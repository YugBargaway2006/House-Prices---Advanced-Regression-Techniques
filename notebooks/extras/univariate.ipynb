# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('../../dataset/train_unprocessed.csv')

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(df['MiscVal'], bins=50, kde=True)
# Out:
# <Axes: xlabel='MiscVal', ylabel='Count'>

# %%
df['SaleCondition'].value_counts().plot(kind='bar', figsize=(10, 6))
# Out:
# <Axes: xlabel='SaleCondition'>

# %% [markdown]
# ## Numerical - Numerical

# %%
sns.scatterplot(x='1stFlrSF', y='SalePrice', data=df, style='CentralAir')
# Out:
# <Axes: xlabel='1stFlrSF', ylabel='SalePrice'>

# %%
# Bar Plor: Numerical - Categroical
sns.barplot(x='GrLivArea', y='SalePrice', data=df)

# %%
sns.boxplot(x='CentralAir', y='SalePrice', data=df)
# Out:
# <Axes: xlabel='CentralAir', ylabel='SalePrice'>

# %%
sns.displot(df['CentralAir'])
# Out:
# c:\Users\yugba\anaconda3\envs\6.86x\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Categorical - Categorical
sns.heatmap(pd.crosstab(df['MSSubClass'], df['MSZoning']))
# Out:
# <Axes: xlabel='MSZoning', ylabel='MSSubClass'>

# %%
sns.pairplot(df)
